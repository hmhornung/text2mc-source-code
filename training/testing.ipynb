# %%
import os
import sys
import json
import math
import pandas as pd
import numpy as np


import torch
from torch.utils.data import Dataset
from MinecraftVAEDataset import MinecraftVAEDataset
# Out:
# INFO - PyMCTranslate Version 385

# %%
dataset = MinecraftVAEDataset(data_path='../../data/MinecraftVAEDataset/', mask_threshold=0)
# Out:
# started making dataset
# Total RAM: 137.36 GB
# Used RAM: 14.24 GB
# RAM Usage (%): 10.4%
#
# Added 0 blocks for potential tranformations
# Added 0 blocks for potential tranformations
# done loading dataset
# Total RAM: 137.36 GB
# Used RAM: 63.61 GB
# RAM Usage (%): 46.3%
#
# done with masking dataset
# Total RAM: 137.36 GB
# Used RAM: 63.46 GB
# RAM Usage (%): 46.2%
#
# done with heatmaps dataset
# Total RAM: 137.36 GB
# Used RAM: 112.97 GB
# RAM Usage (%): 82.2%

# %%
empty_builds
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 empty_builds
#
# NameError: name 'empty_builds' is not defined

# %%
dataset.arr2schem(dataset._transform(dataset.samples[1], True, 3), './', "test_schem")
# Out:
# Successfully saved schematic to test_schem.schem

# %%
dataset.sample_files[1206]
# Out:
# 'batch_184_4775.npy'
